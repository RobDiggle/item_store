# %%
class task:
    def __init__(self, name, description, completed):
        self.name = name
        self.description = description
        self.completed = completed

task_list = {
      "Understanding Functions & Scope: " : task("Understanding Functions & Scope: ", "-Functions\n-Scope", False),
      "Loops & Sequences :" : task("Loops & Sequences :" , "-Lists\n-List methods\n-Tuple methods\n-Enumerate & Zip", False),
      "Dictionaries & Sets :" : task("Dictionaries & Sets :" , "-Looping over a dictionary\n" , False),
      "Error handling :" : task("Error handling :" , "-Exception handling\n-Raise statement\n", False),
      "Classes & Objects :" : task("Classes & Objects :" , "-How do classes work\n-What are methos/attributes?\n-Special methods\n-Handling Object attributes dynamically", False),
      "Object Oriented Programming :" : task("Object Oriented Programming :" , "-Encapsulation\n-Getters & Setters\n-Inheritance\n-Polymorphism\n-Name mangling", False)
            }

for count, task in enumerate(task_list.values(), start=1):
    print(f'{count}.          {task.name}\n')
    print(f'{task.description}\n')
    print(f"Is the task completed?\n              {task.completed}\n")
# Out:
# 1.          Understanding Functions & Scope:
#
# -Functions
# -Scope
#
# Is the task completed?
#               False
#
# 2.          Loops & Sequences :
#
# -Lists
# -List methods
# -Tuple methods
# -Enumerate & Zip
#
# Is the task completed?
#               False
#
# 3.          Dictionaries & Sets :
#
# -Looping over a dictionary
#
#
# Is the task completed?
#               False
#
# 4.          Error handling :
#
# -Exception handling
# -Raise statement
#
#
# Is the task completed?
#               False
#
# 5.          Classes & Objects :
#
# -How do classes work
# -What are methos/attributes?
# -Special methods
# -Handling Object attributes dynamically
#
# Is the task completed?
#               False
#
# 6.          Object Oriented Programming :
#
# -Encapsulation
# -Getters & Setters
# -Inheritance
# -Polymorphism
# -Name mangling
#
# Is the task completed?
#               False

# %%
money = 100

class store_item:
    def __init__(self, name, quantity, price, in_stock):
        self.name = name
        self.quantity = quantity
        self.price = price
        self.in_stock = in_stock

    def item_info(self):
        global money
        
        print(f"Item name: {self.name} \n\nThe item price is ${self.price}.00\n")
        if self.in_stock == True:
            print(f"{self.name} is currently in stock.\n")
            purchase = input("Would you like to purchase this item?").lower()
            if "yes" in purchase and money >= self.price:
                money -= self.price
                print(f"\nYou have purchased a {self.name}!\n")
                print(f"You have ${money}.00 left.\n")
                shopping_cart.append(self.name)
                print(f"SHOPPING CART CONTENTS: \n{shopping_cart}\n")
            if "yes" in purchase and money <= self.price:
                    print("You do not have sufficient funds to purchase this item.")
            if "no" in purchase:
                print("Item not purchased.\n")
        return money



book = store_item("Book", 100, 12, True)
desk = store_item("Desk", 100, 40, True)
coffee_mug = store_item("Coffee mug", 100, 10, True)
laptop = store_item("Laptop", 20, 100, True)
shopping_cart = []

book.item_info()
desk.item_info()
coffee_mug.item_info()
laptop.item_info()
# Out:
# Item name: Book
#
# The item price is $12.00
#
# Book is currently in stock.
#
#
# You have purchased a Book!
#
# You have $88.00 left.
#
# SHOPPING CART CONTENTS:
# ['Book']
#
# Item name: Desk
#
# The item price is $40.00
#
# Desk is currently in stock.
#
#
# You have purchased a Desk!
#
# You have $48.00 left.
#
# SHOPPING CART CONTENTS:
# ['Book', 'Desk']
#
# Item name: Coffee mug
#
# The item price is $10.00
#
# Coffee mug is currently in stock.
#
#
# You have purchased a Coffee mug!
#
# You have $38.00 left.
#
# SHOPPING CART CONTENTS:
# ['Book', 'Desk', 'Coffee mug']
#
# Item name: Laptop
#
# The item price is $100.00
#
# Laptop is currently in stock.
#
# You do not have sufficient funds to purchase this item.
# 38

# %%
class task:
    def __init__(self, name, description, completed):
        self.name = name
        self.description = description
        self.completed = completed

def add_task(task_list):
    new_task = input("New task name?")
    new_task_description = input("New task description.")
    task_list[new_task] = task(new_task, new_task_description, False)

task_list = {
      "Understanding Functions & Scope: " : task("Coding practice", "Practice on free code camp, mess around in Jupyter notebooks & refine Kaiju battle", False),
      "Loops & Sequences :" : task("Clean my room", "Put clothes away, put dirty clothes in bin, take garbage out etc.", False),
      "Dictionaries & Sets :" : task(),
      "Error handling :" : task(),
      "Classes & Objects :" : task(),
      "Object Oriented Programming :" : task()
            }
while len(task_list) < 5:
    add_task(task_list)

for task in task_list.values():
    print(f'{task.name}\n')
    print(f'{task.description}\n')
